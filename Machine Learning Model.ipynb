# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\galle\Desktop\fbref_laliga_2024.csv', sep=';')
df = df.iloc[:20,:]
df.columns
# Out:
# Index(['Equipo', 'PJ', 'PG', 'PE', 'PP', 'GF', 'GC', 'DG', 'Pts', 'Pts/PJ',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Asistencia'],
#       dtype='object')

# %%
import seaborn as sns
df_numeros = df.select_dtypes(include='number')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Equipo      20 non-null     object
#  1   PJ          20 non-null     int64
#  2   PG          20 non-null     int64
#  3   PE          20 non-null     int64
#  4   PP          20 non-null     int64
#  5   GF          20 non-null     int64
#  6   GC          20 non-null     int64
#  7   DG          20 non-null     int64
#  8   Pts         20 non-null     int64
#  9   Pts/PJ      20 non-null     float64
#  10  xG          20 non-null     float64
#  11  xGA         20 non-null     float64
#  12  xGD         20 non-null     float64
#  13  xGD/90      20 non-null     float64
#  14  Asistencia  20 non-null     object
# dtypes: float64(5), int64(8), object(2)
# memory usage: 2.5+ KB

# %%
#sns.pairplot(df_numeros)
df_subset = df_numeros.iloc[:, :5]
sns.pairplot(df_subset)
